# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 708

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sergiyevsk
# Processing Record 2 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 3 of Set 1 | pacific grove
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | airai
# Processing Record 6 of Set 1 | horsham
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | jingcheng
# Processing Record 10 of Set 1 | ilulissat
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | fairbanks
# Processing Record 15 of Set 1 | portland
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | alofi
# Processing Record 18 of Set 1 | houma
# Processing Record 19 of Set 1 | ornskoldsvik
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | yar-sale
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | droitwich
# Processing Record 29 of Set 1 | caravelas
# Processing Record 30 of Set 1 | broome
# Processing Record 31 of Set 1 | uvira
# Processing Record 32 of Set 1 | diego de almagro
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | norman wells
# Processing Record 35 of Set 1 | pauini
# Processing Record 36 of Set 1 | kruisfontein
# Processing Record 37 of Set 1 | katsuura
# Processing Record 38 of Set 1 | kailua
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | swan hill
# Processing Record 41 of Set 1 | hasaki
# Processing Record 42 of Set 1 | acolla
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | senador jose porfirio
# Processing Record 45 of Set 1 | trofors
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | beaverton
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | pachino
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | tura
# Processing Record 4 of Set 2 | baker city
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | skibbereen
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | harbour breton
# Processing Record 9 of Set 2 | namwala
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 15 of Set 2 | roald
# Processing Record 16 of Set 2 | praia
# Processing Record 17 of Set 2 | luderitz
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | progreso
# Processing Record 20 of Set 2 | upernavik
# Processing Record 21 of Set 2 | puerto escondido
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | walvis bay
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | japura
# Processing Record 28 of Set 2 | baykit
# Processing Record 29 of Set 2 | rocha
# Processing Record 30 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 2 | salalah
# Processing Record 32 of Set 2 | talnakh
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | sarkand
# Processing Record 35 of Set 2 | richards bay
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | emerald
# Processing Record 38 of Set 2 | basco
# Processing Record 39 of Set 2 | irbeyskoye
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | roma
# Processing Record 45 of Set 2 | ahipara
# Processing Record 46 of Set 2 | isangel
# Processing Record 47 of Set 2 | leh
# Processing Record 48 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 2 | tsabong
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | straldza
# City not found. Skipping...
# Processing Record 2 of Set 3 | trincomalee
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | bafra
# Processing Record 6 of Set 3 | saint george
# Processing Record 7 of Set 3 | havre-saint-pierre
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | margate
# Processing Record 10 of Set 3 | kavieng
# Processing Record 11 of Set 3 | chuy
# Processing Record 12 of Set 3 | visby
# Processing Record 13 of Set 3 | yafran
# Processing Record 14 of Set 3 | lata
# Processing Record 15 of Set 3 | saint-pierre
# Processing Record 16 of Set 3 | chuguyevka
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | bograd
# Processing Record 19 of Set 3 | dong hoi
# Processing Record 20 of Set 3 | elko
# Processing Record 21 of Set 3 | garissa
# Processing Record 22 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 3 | namibe
# Processing Record 24 of Set 3 | ust-tarka
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | geraldton
# Processing Record 27 of Set 3 | clyde river
# Processing Record 28 of Set 3 | iqaluit
# Processing Record 29 of Set 3 | flin flon
# Processing Record 30 of Set 3 | cortland
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | ola
# Processing Record 33 of Set 3 | guerrero negro
# Processing Record 34 of Set 3 | boyolangu
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | buraydah
# Processing Record 37 of Set 3 | spearfish
# Processing Record 38 of Set 3 | uribia
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 3 | deputatskiy
# Processing Record 41 of Set 3 | moyale
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | naze
# Processing Record 44 of Set 3 | langfang
# Processing Record 45 of Set 3 | saint-gilles
# Processing Record 46 of Set 3 | vaini
# Processing Record 47 of Set 3 | zerind
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | albany
# Processing Record 1 of Set 4 | codrington
# Processing Record 2 of Set 4 | tuktoyaktuk
# Processing Record 3 of Set 4 | muromtsevo
# Processing Record 4 of Set 4 | makung
# City not found. Skipping...
# Processing Record 5 of Set 4 | lulea
# Processing Record 6 of Set 4 | langenburg
# Processing Record 7 of Set 4 | severo-kurilsk
# Processing Record 8 of Set 4 | comodoro rivadavia
# Processing Record 9 of Set 4 | luchegorsk
# Processing Record 10 of Set 4 | luganville
# Processing Record 11 of Set 4 | touros
# Processing Record 12 of Set 4 | santa cruz
# Processing Record 13 of Set 4 | marsh harbour
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | hailar
# Processing Record 18 of Set 4 | seljord
# Processing Record 19 of Set 4 | lasa
# Processing Record 20 of Set 4 | lagoa
# Processing Record 21 of Set 4 | port hardy
# Processing Record 22 of Set 4 | catamarca
# Processing Record 23 of Set 4 | numaligarh
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | inirida
# Processing Record 28 of Set 4 | gambela
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | bilma
# Processing Record 31 of Set 4 | labuhan
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | abu samrah
# Processing Record 34 of Set 4 | cap malheureux
# Processing Record 35 of Set 4 | puerto penasco
# Processing Record 36 of Set 4 | yeppoon
# Processing Record 37 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 4 | bengkulu
# Processing Record 39 of Set 4 | yaan
# Processing Record 40 of Set 4 | shenjiamen
# Processing Record 41 of Set 4 | meulaboh
# Processing Record 42 of Set 4 | dese
# Processing Record 43 of Set 4 | vostok
# Processing Record 44 of Set 4 | haines junction
# Processing Record 45 of Set 4 | taoudenni
# Processing Record 46 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 4 | tenno
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | okato
# Processing Record 50 of Set 4 | dieppe
# Processing Record 1 of Set 5 | padang
# Processing Record 2 of Set 5 | sola
# Processing Record 3 of Set 5 | alexandria
# Processing Record 4 of Set 5 | san quintin
# Processing Record 5 of Set 5 | nemuro
# Processing Record 6 of Set 5 | yambio
# Processing Record 7 of Set 5 | alice springs
# Processing Record 8 of Set 5 | severodvinsk
# Processing Record 9 of Set 5 | yellowknife
# Processing Record 10 of Set 5 | moron
# Processing Record 11 of Set 5 | pangnirtung
# Processing Record 12 of Set 5 | salym
# Processing Record 13 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 5 | sinnamary
# Processing Record 15 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 5 | khandyga
# Processing Record 17 of Set 5 | bambanglipuro
# Processing Record 18 of Set 5 | mezen
# Processing Record 19 of Set 5 | araouane
# Processing Record 20 of Set 5 | rio gallegos
# Processing Record 21 of Set 5 | tucuman
# Processing Record 22 of Set 5 | kununurra
# Processing Record 23 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 5 | bilibino
# Processing Record 25 of Set 5 | jumla
# Processing Record 26 of Set 5 | kalispell
# Processing Record 27 of Set 5 | itarema
# Processing Record 28 of Set 5 | arua
# Processing Record 29 of Set 5 | namatanai
# Processing Record 30 of Set 5 | weinsberg
# Processing Record 31 of Set 5 | muroran
# Processing Record 32 of Set 5 | martapura
# Processing Record 33 of Set 5 | vila franca do campo
# Processing Record 34 of Set 5 | banfora
# Processing Record 35 of Set 5 | mackay
# Processing Record 36 of Set 5 | eresos
# Processing Record 37 of Set 5 | constitucion
# Processing Record 38 of Set 5 | promissao
# Processing Record 39 of Set 5 | los llanos de aridane
# Processing Record 40 of Set 5 | gimli
# Processing Record 41 of Set 5 | naldurg
# Processing Record 42 of Set 5 | natalio
# Processing Record 43 of Set 5 | yarmouth
# Processing Record 44 of Set 5 | tete
# Processing Record 45 of Set 5 | ikom
# Processing Record 46 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 5 | ambilobe
# Processing Record 48 of Set 5 | yumen
# Processing Record 49 of Set 5 | okhotsk
# Processing Record 50 of Set 5 | cortez
# Processing Record 1 of Set 6 | antalaha
# Processing Record 2 of Set 6 | mount gambier
# Processing Record 3 of Set 6 | kodiak
# Processing Record 4 of Set 6 | sao borja
# Processing Record 5 of Set 6 | vanimo
# Processing Record 6 of Set 6 | karratha
# Processing Record 7 of Set 6 | salekhard
# Processing Record 8 of Set 6 | avera
# Processing Record 9 of Set 6 | makakilo city
# Processing Record 10 of Set 6 | kangaatsiaq
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | fuyu
# Processing Record 13 of Set 6 | mar del plata
# Processing Record 14 of Set 6 | parabel
# Processing Record 15 of Set 6 | asau
# Processing Record 16 of Set 6 | tuatapere
# Processing Record 17 of Set 6 | urusha
# Processing Record 18 of Set 6 | vilhena
# Processing Record 19 of Set 6 | esperance
# Processing Record 20 of Set 6 | vestmannaeyjar
# Processing Record 21 of Set 6 | vila do maio
# Processing Record 22 of Set 6 | qaqortoq
# Processing Record 23 of Set 6 | savalou
# Processing Record 24 of Set 6 | miracatu
# Processing Record 25 of Set 6 | mount isa
# Processing Record 26 of Set 6 | aleksandrov gay
# Processing Record 27 of Set 6 | san patricio
# Processing Record 28 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 6 | port-gentil
# Processing Record 30 of Set 6 | xining
# Processing Record 31 of Set 6 | hualmay
# Processing Record 32 of Set 6 | fortuna
# Processing Record 33 of Set 6 | tommot
# Processing Record 34 of Set 6 | smithers
# Processing Record 35 of Set 6 | lakes entrance
# Processing Record 36 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | adrar
# Processing Record 39 of Set 6 | gat
# Processing Record 40 of Set 6 | kargil
# Processing Record 41 of Set 6 | khash
# Processing Record 42 of Set 6 | cidreira
# Processing Record 43 of Set 6 | sao mateus do sul
# Processing Record 44 of Set 6 | mersing
# Processing Record 45 of Set 6 | fukue
# Processing Record 46 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 6 | guangyuan
# Processing Record 48 of Set 6 | sainte-marie
# Processing Record 49 of Set 6 | hami
# Processing Record 50 of Set 6 | nelson bay
# Processing Record 1 of Set 7 | bandarbeyla
# Processing Record 2 of Set 7 | ngunguru
# Processing Record 3 of Set 7 | ancud
# Processing Record 4 of Set 7 | bayan
# Processing Record 5 of Set 7 | magadan
# Processing Record 6 of Set 7 | matsanga
# City not found. Skipping...
# Processing Record 7 of Set 7 | talara
# Processing Record 8 of Set 7 | silver city
# Processing Record 9 of Set 7 | kangasala
# Processing Record 10 of Set 7 | korla
# Processing Record 11 of Set 7 | san pedro
# Processing Record 12 of Set 7 | iquique
# Processing Record 13 of Set 7 | linchuan
# City not found. Skipping...
# Processing Record 14 of Set 7 | nikolayevsk-na-amure
# Processing Record 15 of Set 7 | codo
# Processing Record 16 of Set 7 | juegang
# Processing Record 17 of Set 7 | mutoko
# Processing Record 18 of Set 7 | gamba
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 7 | grand gaube
# Processing Record 22 of Set 7 | pitimbu
# Processing Record 23 of Set 7 | masallatah
# Processing Record 24 of Set 7 | cayenne
# Processing Record 25 of Set 7 | sorong
# Processing Record 26 of Set 7 | boa vista
# Processing Record 27 of Set 7 | neuquen
# Processing Record 28 of Set 7 | kayunga
# Processing Record 29 of Set 7 | camacha
# Processing Record 30 of Set 7 | sebezh
# Processing Record 31 of Set 7 | svetlaya
# Processing Record 32 of Set 7 | dolores
# Processing Record 33 of Set 7 | belmonte
# Processing Record 34 of Set 7 | havoysund
# Processing Record 35 of Set 7 | riyadh
# Processing Record 36 of Set 7 | hammerfest
# Processing Record 37 of Set 7 | vila velha
# Processing Record 38 of Set 7 | bambous virieux
# Processing Record 39 of Set 7 | koboldo
# City not found. Skipping...
# Processing Record 40 of Set 7 | santa isabel do rio negro
# Processing Record 41 of Set 7 | carnarvon
# Processing Record 42 of Set 7 | half moon bay
# Processing Record 43 of Set 7 | taiyuan
# Processing Record 44 of Set 7 | del rio
# Processing Record 45 of Set 7 | jinka
# Processing Record 46 of Set 7 | kalmunai
# Processing Record 47 of Set 7 | georgetown
# Processing Record 48 of Set 7 | mahebourg
# Processing Record 49 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 50 of Set 7 | lorengau
# Processing Record 1 of Set 8 | chernyshevskiy
# Processing Record 2 of Set 8 | riberalta
# Processing Record 3 of Set 8 | tremedal
# Processing Record 4 of Set 8 | zonguldak
# Processing Record 5 of Set 8 | damietta
# Processing Record 6 of Set 8 | kamenka
# Processing Record 7 of Set 8 | carutapera
# Processing Record 8 of Set 8 | monrovia
# Processing Record 9 of Set 8 | salani
# Processing Record 10 of Set 8 | arrifes
# Processing Record 11 of Set 8 | ust-maya
# Processing Record 12 of Set 8 | srandakan
# Processing Record 13 of Set 8 | terme
# Processing Record 14 of Set 8 | zagyvaszanto
# Processing Record 15 of Set 8 | yining
# Processing Record 16 of Set 8 | maneadero
# Processing Record 17 of Set 8 | mokobeng
# Processing Record 18 of Set 8 | kundla
# Processing Record 19 of Set 8 | oga
# Processing Record 20 of Set 8 | marawi
# Processing Record 21 of Set 8 | haverfordwest
# Processing Record 22 of Set 8 | bathsheba
# Processing Record 23 of Set 8 | terrace bay
# Processing Record 24 of Set 8 | road town
# Processing Record 25 of Set 8 | rawson
# Processing Record 26 of Set 8 | cururupu
# Processing Record 27 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 28 of Set 8 | george
# Processing Record 29 of Set 8 | zeya
# Processing Record 30 of Set 8 | ginda
# Processing Record 31 of Set 8 | fonte boa
# Processing Record 32 of Set 8 | hamilton
# Processing Record 33 of Set 8 | madona
# Processing Record 34 of Set 8 | kijang
# Processing Record 35 of Set 8 | santa maria
# Processing Record 36 of Set 8 | port shepstone
# Processing Record 37 of Set 8 | saint andrews
# Processing Record 38 of Set 8 | muravlenko
# Processing Record 39 of Set 8 | keti bandar
# Processing Record 40 of Set 8 | aksarka
# Processing Record 41 of Set 8 | vytegra
# Processing Record 42 of Set 8 | sijunjung
# Processing Record 43 of Set 8 | dingle
# Processing Record 44 of Set 8 | dhidhdhoo
# Processing Record 45 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 46 of Set 8 | sao miguel do araguaia
# Processing Record 47 of Set 8 | fort nelson
# Processing Record 48 of Set 8 | college
# Processing Record 49 of Set 8 | dauriya
# Processing Record 50 of Set 8 | sibolga
# Processing Record 1 of Set 9 | cherskiy
# Processing Record 2 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 3 of Set 9 | holme
# Processing Record 4 of Set 9 | trinidad
# Processing Record 5 of Set 9 | olafsvik
# Processing Record 6 of Set 9 | mataram
# Processing Record 7 of Set 9 | andijon
# Processing Record 8 of Set 9 | pochutla
# Processing Record 9 of Set 9 | port hedland
# Processing Record 10 of Set 9 | yuanping
# Processing Record 11 of Set 9 | puerto baquerizo moreno
# Processing Record 12 of Set 9 | nouadhibou
# Processing Record 13 of Set 9 | yuncheng
# Processing Record 14 of Set 9 | harnosand
# Processing Record 15 of Set 9 | alyangula
# Processing Record 16 of Set 9 | whitecourt
# Processing Record 17 of Set 9 | salinas
# Processing Record 18 of Set 9 | guozhen
# Processing Record 19 of Set 9 | laguna
# Processing Record 20 of Set 9 | singaraja
# Processing Record 21 of Set 9 | krotovka
# Processing Record 22 of Set 9 | arraial do cabo
# Processing Record 23 of Set 9 | les cayes
# Processing Record 24 of Set 9 | dicabisagan
# Processing Record 25 of Set 9 | moerai
# Processing Record 26 of Set 9 | ponta pora
# Processing Record 27 of Set 9 | itaituba
# Processing Record 28 of Set 9 | champerico
# Processing Record 29 of Set 9 | lavrentiya
# Processing Record 30 of Set 9 | pringsewu
# Processing Record 31 of Set 9 | tilichiki
# Processing Record 32 of Set 9 | lukovetskiy
# Processing Record 33 of Set 9 | kawalu
# Processing Record 34 of Set 9 | hambantota
# Processing Record 35 of Set 9 | sovetskiy
# Processing Record 36 of Set 9 | necochea
# Processing Record 37 of Set 9 | kieta
# Processing Record 38 of Set 9 | narsaq
# Processing Record 39 of Set 9 | sorland
# Processing Record 40 of Set 9 | rabo de peixe
# Processing Record 41 of Set 9 | auki
# Processing Record 42 of Set 9 | itacoatiara
# Processing Record 43 of Set 9 | tiksi
# Processing Record 44 of Set 9 | nome
# Processing Record 45 of Set 9 | la tuque
# Processing Record 46 of Set 9 | ocos
# Processing Record 47 of Set 9 | trat
# Processing Record 48 of Set 9 | windhoek
# Processing Record 49 of Set 9 | tumaco
# Processing Record 50 of Set 9 | ouesso
# Processing Record 1 of Set 10 | san vicente
# Processing Record 2 of Set 10 | atar
# Processing Record 3 of Set 10 | chapais
# Processing Record 4 of Set 10 | biak
# Processing Record 5 of Set 10 | inhambane
# Processing Record 6 of Set 10 | muisne
# Processing Record 7 of Set 10 | niamey
# Processing Record 8 of Set 10 | quatre cocos
# Processing Record 9 of Set 10 | new glasgow
# Processing Record 10 of Set 10 | porbandar
# Processing Record 11 of Set 10 | oriximina
# Processing Record 12 of Set 10 | doka
# Processing Record 13 of Set 10 | coos bay
# Processing Record 14 of Set 10 | manggar
# Processing Record 15 of Set 10 | cecina
# Processing Record 16 of Set 10 | ozernovskiy
# Processing Record 17 of Set 10 | uruzgan
# Processing Record 18 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 10 | gaoua
# Processing Record 20 of Set 10 | chipata
# Processing Record 21 of Set 10 | egvekinot
# Processing Record 22 of Set 10 | cauquenes
# Processing Record 23 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 24 of Set 10 | maningrida
# Processing Record 25 of Set 10 | natal
# Processing Record 26 of Set 10 | mogok
# Processing Record 27 of Set 10 | boatlaname
# City not found. Skipping...
# Processing Record 28 of Set 10 | jiayuguan
# Processing Record 29 of Set 10 | flinders
# Processing Record 30 of Set 10 | velka bites
# Processing Record 31 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 10 | nanortalik
# Processing Record 33 of Set 10 | port lincoln
# Processing Record 34 of Set 10 | port blair
# Processing Record 35 of Set 10 | lazaro cardenas
# Processing Record 36 of Set 10 | dongzhen
# Processing Record 37 of Set 10 | ostrovnoy
# Processing Record 38 of Set 10 | brae
# Processing Record 39 of Set 10 | rio brilhante
# Processing Record 40 of Set 10 | russell
# Processing Record 41 of Set 10 | nyzhnya duvanka
# Processing Record 42 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 10 | kota
# Processing Record 44 of Set 10 | maloyaz
# City not found. Skipping...
# Processing Record 45 of Set 10 | abha
# Processing Record 46 of Set 10 | trapani
# Processing Record 47 of Set 10 | kismayo
# Processing Record 48 of Set 10 | kingsland
# Processing Record 49 of Set 10 | vao
# Processing Record 50 of Set 10 | morondava
# Processing Record 1 of Set 11 | calella
# Processing Record 2 of Set 11 | lesogorskiy
# Processing Record 3 of Set 11 | khor
# Processing Record 4 of Set 11 | chiang klang
# Processing Record 5 of Set 11 | takoradi
# Processing Record 6 of Set 11 | grindavik
# Processing Record 7 of Set 11 | lishu
# Processing Record 8 of Set 11 | nauta
# Processing Record 9 of Set 11 | poum
# Processing Record 10 of Set 11 | tautira
# Processing Record 11 of Set 11 | zaraza
# Processing Record 12 of Set 11 | katherine
# Processing Record 13 of Set 11 | rio claro
# Processing Record 14 of Set 11 | kushiro
# Processing Record 15 of Set 11 | zhoucheng
# Processing Record 16 of Set 11 | iwanai
# Processing Record 17 of Set 11 | the pas
# Processing Record 18 of Set 11 | provost
# Processing Record 19 of Set 11 | kuybysheve
# Processing Record 20 of Set 11 | melfi
# Processing Record 21 of Set 11 | wenatchee
# Processing Record 22 of Set 11 | malakal
# Processing Record 23 of Set 11 | sambava
# Processing Record 24 of Set 11 | chaplynka
# Processing Record 25 of Set 11 | baghdad
# Processing Record 26 of Set 11 | sayyan
# Processing Record 27 of Set 11 | sobolevo
# Processing Record 28 of Set 11 | northam
# Processing Record 29 of Set 11 | beyneu
# Processing Record 30 of Set 11 | nhulunbuy
# Processing Record 31 of Set 11 | leshukonskoye
# Processing Record 32 of Set 11 | tazovskiy
# Processing Record 33 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 11 | port macquarie
# Processing Record 35 of Set 11 | mitchell
# Processing Record 36 of Set 11 | amga
# Processing Record 37 of Set 11 | shache
# Processing Record 38 of Set 11 | sistranda
# Processing Record 39 of Set 11 | san juan
# Processing Record 40 of Set 11 | isla mujeres
# Processing Record 41 of Set 11 | seoul
# Processing Record 42 of Set 11 | shitanjing
# Processing Record 43 of Set 11 | solnechnyy
# Processing Record 44 of Set 11 | saint-augustin
# Processing Record 45 of Set 11 | dutlwe
# Processing Record 46 of Set 11 | te anau
# Processing Record 47 of Set 11 | chara
# Processing Record 48 of Set 11 | sangamner
# Processing Record 49 of Set 11 | tubuala
# Processing Record 50 of Set 11 | saint-joseph
# Processing Record 1 of Set 12 | coronado
# Processing Record 2 of Set 12 | cookshire
# City not found. Skipping...
# Processing Record 3 of Set 12 | anadyr
# Processing Record 4 of Set 12 | bull savanna
# Processing Record 5 of Set 12 | batagay
# Processing Record 6 of Set 12 | ballina
# Processing Record 7 of Set 12 | huarmey
# Processing Record 8 of Set 12 | feldbach
# Processing Record 9 of Set 12 | sartana
# Processing Record 10 of Set 12 | chaklasi
# Processing Record 11 of Set 12 | roanoke rapids
# Processing Record 12 of Set 12 | berlevag
# Processing Record 13 of Set 12 | jequitinhonha
# Processing Record 14 of Set 12 | moyo
# Processing Record 15 of Set 12 | hofn
# Processing Record 16 of Set 12 | erzin
# Processing Record 17 of Set 12 | manavalakurichi
# Processing Record 18 of Set 12 | kenda
# Processing Record 19 of Set 12 | bandar-e lengeh
# Processing Record 20 of Set 12 | isoka
# Processing Record 21 of Set 12 | wageningen
# Processing Record 22 of Set 12 | coquimbo
# Processing Record 23 of Set 12 | bend
# Processing Record 24 of Set 12 | henties bay
# Processing Record 25 of Set 12 | letlhakane
# Processing Record 26 of Set 12 | ust-uda
# Processing Record 27 of Set 12 | toumodi
# Processing Record 28 of Set 12 | masuda
# Processing Record 29 of Set 12 | bonthe
# Processing Record 30 of Set 12 | ibra
# Processing Record 31 of Set 12 | sakakah
# Processing Record 32 of Set 12 | turukhansk
# Processing Record 33 of Set 12 | mayo
# Processing Record 34 of Set 12 | polewali
# Processing Record 35 of Set 12 | mandiana
# Processing Record 36 of Set 12 | sao lourenco do sul
# Processing Record 37 of Set 12 | martil
# Processing Record 38 of Set 12 | senneterre
# Processing Record 39 of Set 12 | xai-xai
# Processing Record 40 of Set 12 | dali
# Processing Record 41 of Set 12 | san carlos del zulia
# Processing Record 42 of Set 12 | alugan
# Processing Record 43 of Set 12 | jalu
# Processing Record 44 of Set 12 | barranca de upia
# Processing Record 45 of Set 12 | yarada
# Processing Record 46 of Set 12 | ouango
# Processing Record 47 of Set 12 | soyo
# Processing Record 48 of Set 12 | umm kaddadah
# Processing Record 49 of Set 12 | novikovo
# Processing Record 50 of Set 12 | chaumont
# Processing Record 1 of Set 13 | itupiranga
# Processing Record 2 of Set 13 | ipixuna
# Processing Record 3 of Set 13 | liverpool
# Processing Record 4 of Set 13 | medea
# Processing Record 5 of Set 13 | darhan
# Processing Record 6 of Set 13 | ko samui
# Processing Record 7 of Set 13 | chabahar
# Processing Record 8 of Set 13 | xingyi
# Processing Record 9 of Set 13 | gladstone
# Processing Record 10 of Set 13 | pyapon
# Processing Record 11 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 13 | jamame
# Processing Record 13 of Set 13 | parry sound
# Processing Record 14 of Set 13 | campbell river
# Processing Record 15 of Set 13 | hirara
# Processing Record 16 of Set 13 | sitka
# Processing Record 17 of Set 13 | rosarito
# Processing Record 18 of Set 13 | masuguru
# Processing Record 19 of Set 13 | mumford
# Processing Record 20 of Set 13 | lokoja
# Processing Record 21 of Set 13 | hastings
# Processing Record 22 of Set 13 | bosaso
# Processing Record 23 of Set 13 | zambezi
# Processing Record 24 of Set 13 | najran
# Processing Record 25 of Set 13 | beringovskiy
# Processing Record 26 of Set 13 | miri
# Processing Record 27 of Set 13 | lodwar
# Processing Record 28 of Set 13 | ixtapa
# Processing Record 29 of Set 13 | quelimane
# Processing Record 30 of Set 13 | mecca
# Processing Record 31 of Set 13 | saint anthony
# Processing Record 32 of Set 13 | gasa
# Processing Record 33 of Set 13 | itaqui
# Processing Record 34 of Set 13 | ayagoz
# Processing Record 35 of Set 13 | nyurba
# Processing Record 36 of Set 13 | paka
# Processing Record 37 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 13 | pimentel
# Processing Record 39 of Set 13 | santa rosa
# Processing Record 40 of Set 13 | murray bridge
# Processing Record 41 of Set 13 | hovd
# Processing Record 42 of Set 13 | shangrao
# Processing Record 43 of Set 13 | mukhen
# Processing Record 44 of Set 13 | omboue
# Processing Record 45 of Set 13 | hohhot
# Processing Record 46 of Set 13 | santarem
# Processing Record 47 of Set 13 | inongo
# Processing Record 48 of Set 13 | ponta delgada
# Processing Record 49 of Set 13 | magan
# Processing Record 50 of Set 13 | cockburn town
# Processing Record 1 of Set 14 | glogow
# Processing Record 2 of Set 14 | nacala
# Processing Record 3 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 4 of Set 14 | istok
# Processing Record 5 of Set 14 | husavik
# Processing Record 6 of Set 14 | furstenfeld
# Processing Record 7 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 14 | narrabri
# Processing Record 9 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 14 | meadow lake
# Processing Record 11 of Set 14 | mbeya
# Processing Record 12 of Set 14 | alpena
# Processing Record 13 of Set 14 | selma
# Processing Record 14 of Set 14 | nizhniy tsasuchey
# Processing Record 15 of Set 14 | suzu
# City not found. Skipping...
# Processing Record 16 of Set 14 | marystown
# Processing Record 17 of Set 14 | challans
# Processing Record 18 of Set 14 | oistins
# Processing Record 19 of Set 14 | sabya
# Processing Record 20 of Set 14 | cacador
# Processing Record 21 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 14 | arbazh
# Processing Record 23 of Set 14 | kanniyakumari
# Processing Record 24 of Set 14 | rivers
# Processing Record 25 of Set 14 | paraiso
# Processing Record 26 of Set 14 | bowen
# Processing Record 27 of Set 14 | waipawa
# Processing Record 28 of Set 14 | jiuquan
# Processing Record 29 of Set 14 | asyut
# Processing Record 30 of Set 14 | zhigansk
# Processing Record 31 of Set 14 | guanica
# Processing Record 32 of Set 14 | solt
# Processing Record 33 of Set 14 | nyuksenitsa
# Processing Record 34 of Set 14 | sharjah
# Processing Record 35 of Set 14 | uyuni
# Processing Record 36 of Set 14 | altamira
# Processing Record 37 of Set 14 | rapid valley
# Processing Record 38 of Set 14 | atambua
# Processing Record 39 of Set 14 | faya
# Processing Record 40 of Set 14 | saint pete beach
# Processing Record 41 of Set 14 | gari
# Processing Record 42 of Set 14 | kodinsk
# Processing Record 43 of Set 14 | tabou
# Processing Record 44 of Set 14 | borazjan
# Processing Record 45 of Set 14 | kirakira
# Processing Record 46 of Set 14 | nishihara
# Processing Record 47 of Set 14 | kota kinabalu
# Processing Record 48 of Set 14 | taga
# Processing Record 49 of Set 14 | aksu
# Processing Record 50 of Set 14 | makaleng
# Processing Record 1 of Set 15 | aligudarz
# Processing Record 2 of Set 15 | abu zabad
# Processing Record 3 of Set 15 | juarez
# Processing Record 4 of Set 15 | arkhara
# Processing Record 5 of Set 15 | acapulco
# Processing Record 6 of Set 15 | blagoyevo
# Processing Record 7 of Set 15 | qasigiannguit
# Processing Record 8 of Set 15 | ulladulla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Sergiyevsk      RU  53.9413   51.1650     38.70        53         100
# 1  Pacific Grove      US  36.6177 -121.9166     70.11        70           1
# 2      Cape Town      ZA -33.9258   18.4232     70.12        66         100
# 3          Airai      TL  -8.9266  125.4092     62.11        84          91
# 4        Horsham      GB  51.0640   -0.3272     59.65        68          40
# 5   Punta Arenas      CL -53.1500  -70.9167     57.31        47           0
# 6      Busselton      AU -33.6500  115.3333     47.05        86          23
# 7      Jingcheng      CN  32.0142  120.2625     60.04        64          77
# 8      Ilulissat      GL  69.2167  -51.1000     15.82        48          75
# 9        Mataura      NZ -46.1927  168.8643     46.76        97          43
#
#    Wind Speed Current Description
# 0       15.26     overcast clouds
# 1        3.00           clear sky
# 2        4.52     overcast clouds
# 3        1.52     overcast clouds
# 4       10.36    scattered clouds
# 5       33.38           clear sky
# 6        9.37          few clouds
# 7        5.73          light rain
# 8        5.75       broken clouds
# 9        2.06    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
